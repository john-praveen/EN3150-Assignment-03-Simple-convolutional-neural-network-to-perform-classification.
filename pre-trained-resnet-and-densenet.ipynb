# %%
import os
import random
import shutil
from pathlib import Path

# Set random seed for reproducibility
random.seed(42)

# Source (original) directory and destination (split) directory
src_dir = Path("/kaggle/input/realwaste/realwaste-main/RealWaste")
dst_dir = Path("/kaggle/working/realwaste_split")

# Create train, val, and test directories with class subfolders
splits = ["train", "val", "test"]
for split in splits:
    for cls in os.listdir(src_dir):
        (dst_dir / split / cls).mkdir(parents=True, exist_ok=True)

# Split ratios
train_ratio, val_ratio = 0.7, 0.15  # 70% train, 15% val, 15% test

# Go through each class and copy images
for cls in os.listdir(src_dir):
    cls_dir = src_dir / cls
    images = list(cls_dir.glob("*.jpg")) + list(cls_dir.glob("*.png"))
    random.shuffle(images)

    n_total = len(images)
    n_train = int(train_ratio * n_total)
    n_val = int(val_ratio * n_total)

    for i, img_path in enumerate(images):
        if i < n_train:
            dest = dst_dir / "train" / cls / img_path.name
        elif i < n_train + n_val:
            dest = dst_dir / "val" / cls / img_path.name
        else:
            dest = dst_dir / "test" / cls / img_path.name
        shutil.copy(img_path, dest)

print("✅ Dataset successfully split into train/val/test folders at /kaggle/working/realwaste_split")
# Out:
# ✅ Dataset successfully split into train/val/test folders at /kaggle/working/realwaste_split

# %%
for split in ["train", "val", "test"]:
    path = f"/kaggle/working/realwaste_split/{split}"
    classes = os.listdir(path)
    print(f"{split.upper()} contains {len(classes)} classes: {classes}")
# Out:
# TRAIN contains 9 classes: ['Paper', 'Cardboard', 'Plastic', 'Metal', 'Vegetation', 'Food Organics', 'Textile Trash', 'Glass', 'Miscellaneous Trash']
# VAL contains 9 classes: ['Paper', 'Cardboard', 'Plastic', 'Metal', 'Vegetation', 'Food Organics', 'Textile Trash', 'Glass', 'Miscellaneous Trash']
# TEST contains 9 classes: ['Paper', 'Cardboard', 'Plastic', 'Metal', 'Vegetation', 'Food Organics', 'Textile Trash', 'Glass', 'Miscellaneous Trash']

# %%
for split in ["train", "val", "test"]:
    total = 0
    for cls in os.listdir(f"/kaggle/working/realwaste_split/{split}"):
        n = len(os.listdir(f"/kaggle/working/realwaste_split/{split}/{cls}"))
        total += n
    print(f"{split}: {total} images")
# Out:
# train: 3323 images
# val: 710 images
# test: 719 images

# %%
from PIL import Image
import matplotlib.pyplot as plt
import random

split = "train"
cls = random.choice(os.listdir(f"/kaggle/working/realwaste_split/{split}"))
img_name = random.choice(os.listdir(f"/kaggle/working/realwaste_split/{split}/{cls}"))
img_path = f"/kaggle/working/realwaste_split/{split}/{cls}/{img_name}"

img = Image.open(img_path)
plt.imshow(img)
plt.title(f"{split} | {cls}")
plt.axis("off")
plt.show()

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# Paths to your split dataset
train_dir = '/kaggle/working/realwaste_split/train'
val_dir = '/kaggle/working/realwaste_split/val'
test_dir = '/kaggle/working/realwaste_split/test'

# Check device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Transforms for train, val, and test sets
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# Create datasets
train_dataset = datasets.ImageFolder(train_dir, transform=train_transforms)
val_dataset = datasets.ImageFolder(val_dir, transform=val_transforms)
test_dataset = datasets.ImageFolder(test_dir, transform=val_transforms)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

print(f"Classes: {train_dataset.classes}")
print(f"Train images: {len(train_dataset)}, Val images: {len(val_dataset)}, Test images: {len(test_dataset)}")
# Out:
# Classes: ['Cardboard', 'Food Organics', 'Glass', 'Metal', 'Miscellaneous Trash', 'Paper', 'Plastic', 'Textile Trash', 'Vegetation']
# Train images: 3323, Val images: 710, Test images: 719

# %%
import torchvision

# %%
import numpy as np


# Show a few training images
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title:
        plt.title(title)
    plt.axis('off')

# Get one batch
inputs, classes = next(iter(train_loader))
out = torchvision.utils.make_grid(inputs[:6])
imshow(out, title=[train_dataset.classes[x] for x in classes[:6]])

# %%
import torch.nn as nn
import torchvision.models as models

# Load pretrained ResNet50 model
resnet50 = models.resnet50(pretrained=True)

# Freeze earlier layers to keep pretrained weights
for param in resnet50.parameters():
    param.requires_grad = False

# Replace the final fully connected (FC) layer
num_features = resnet50.fc.in_features
num_classes = len(train_dataset.classes)  
resnet50.fc = nn.Linear(num_features, num_classes)

# Move model to GPU (if available)
resnet50 = resnet50.to(device)

print("Model modified successfully. Ready for training.")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 210MB/s]
# Model modified successfully. Ready for training.

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet50.fc.parameters(), lr=0.001)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=5):
    train_losses, val_losses = [], []
    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        print("-" * 20)

        # TRAINING
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        train_acc = 100 * correct / total

        # VALIDATION
        model.eval()
        val_running_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = 100 * val_correct / val_total

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
        print(f"Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc:.2f}%")

    return model, train_losses, val_losses

# %%
num_epochs = 100  

resnet50, train_losses, val_losses = train_model(
    resnet50, criterion, optimizer, train_loader, val_loader, num_epochs=num_epochs
)
# Out:
# Epoch 1/100
# --------------------
# Train Loss: 1.4019 | Train Acc: 52.99%
# Val Loss:   1.0424 | Val Acc:   64.08%
#
# Epoch 2/100
# --------------------
# Train Loss: 0.9159 | Train Acc: 69.67%
# Val Loss:   0.8505 | Val Acc:   70.99%
#
# Epoch 3/100
# --------------------
# Train Loss: 0.7919 | Train Acc: 73.22%
# Val Loss:   0.8263 | Val Acc:   71.55%
#
# Epoch 4/100
# --------------------
# Train Loss: 0.7339 | Train Acc: 75.26%
# Val Loss:   0.7985 | Val Acc:   71.55%
#
# Epoch 5/100
# --------------------
# Train Loss: 0.6866 | Train Acc: 75.47%
# Val Loss:   0.7328 | Val Acc:   74.23%
#
# Epoch 6/100
# --------------------
# Train Loss: 0.6685 | Train Acc: 76.86%
# Val Loss:   0.7317 | Val Acc:   73.10%
#
# Epoch 7/100
# --------------------
# Train Loss: 0.6076 | Train Acc: 79.15%
# Val Loss:   0.6981 | Val Acc:   75.21%
#
# Epoch 8/100
# --------------------
# Train Loss: 0.5955 | Train Acc: 78.78%
# Val Loss:   0.7347 | Val Acc:   74.37%
#
# Epoch 9/100
# --------------------
# Train Loss: 0.6031 | Train Acc: 78.66%
# Val Loss:   0.6823 | Val Acc:   75.63%
#
# Epoch 10/100
# --------------------
# Train Loss: 0.5548 | Train Acc: 80.65%
# Val Loss:   0.6633 | Val Acc:   76.90%
#
# Epoch 11/100
# --------------------
# Train Loss: 0.5846 | Train Acc: 79.06%
# Val Loss:   0.7001 | Val Acc:   74.93%
#
# Epoch 12/100
# --------------------
# Train Loss: 0.5612 | Train Acc: 80.14%
# Val Loss:   0.6658 | Val Acc:   76.62%
#
# Epoch 13/100
# --------------------
# Train Loss: 0.5209 | Train Acc: 81.79%
# Val Loss:   0.7068 | Val Acc:   76.20%
#
# Epoch 14/100
# --------------------
# Train Loss: 0.5142 | Train Acc: 81.76%
# Val Loss:   0.6810 | Val Acc:   75.77%
#
# Epoch 15/100
# --------------------
# Train Loss: 0.5151 | Train Acc: 81.46%
# Val Loss:   0.6784 | Val Acc:   76.62%
#
# Epoch 16/100
# --------------------
# Train Loss: 0.5227 | Train Acc: 82.06%
# Val Loss:   0.7199 | Val Acc:   75.07%
#
# Epoch 17/100
# --------------------
# Train Loss: 0.5036 | Train Acc: 82.55%
# Val Loss:   0.6533 | Val Acc:   78.59%
#
# Epoch 18/100
# --------------------
# Train Loss: 0.4864 | Train Acc: 82.49%
# Val Loss:   0.6715 | Val Acc:   77.75%
#
# Epoch 19/100
# --------------------
# Train Loss: 0.4993 | Train Acc: 82.46%
# Val Loss:   0.7106 | Val Acc:   76.90%
#
# Epoch 20/100
# --------------------
# Train Loss: 0.4830 | Train Acc: 82.58%
# Val Loss:   0.6925 | Val Acc:   76.76%
#
# Epoch 21/100
# --------------------
# Train Loss: 0.5029 | Train Acc: 81.91%
# Val Loss:   0.6294 | Val Acc:   79.44%
#
# Epoch 22/100
# --------------------
# Train Loss: 0.4784 | Train Acc: 82.70%
# Val Loss:   0.7057 | Val Acc:   74.79%
#
# Epoch 23/100
# --------------------
# Train Loss: 0.4536 | Train Acc: 84.29%
# Val Loss:   0.6485 | Val Acc:   78.31%
#
# Epoch 24/100
# --------------------
# Train Loss: 0.4605 | Train Acc: 83.54%
# Val Loss:   0.7281 | Val Acc:   76.20%
#
# Epoch 25/100
# --------------------
# Train Loss: 0.4436 | Train Acc: 83.96%
# Val Loss:   0.6321 | Val Acc:   78.45%
#
# Epoch 26/100
# --------------------
# Train Loss: 0.4584 | Train Acc: 84.62%
# Val Loss:   0.6313 | Val Acc:   79.86%
#
# Epoch 27/100
# --------------------
# Train Loss: 0.4355 | Train Acc: 84.86%
# Val Loss:   0.6594 | Val Acc:   78.45%
#
# Epoch 28/100
# --------------------
# Train Loss: 0.4374 | Train Acc: 84.89%
# Val Loss:   0.6401 | Val Acc:   77.32%
#
# Epoch 29/100
# --------------------
# Train Loss: 0.4269 | Train Acc: 83.81%
# Val Loss:   0.6276 | Val Acc:   79.86%
#
# Epoch 30/100
# --------------------
# Train Loss: 0.4333 | Train Acc: 85.01%
# Val Loss:   0.6310 | Val Acc:   78.87%
#
# Epoch 31/100
# --------------------
# Train Loss: 0.4081 | Train Acc: 85.13%
# Val Loss:   0.6182 | Val Acc:   79.01%
#
# Epoch 32/100
# --------------------
# Train Loss: 0.4059 | Train Acc: 85.46%
# Val Loss:   0.7293 | Val Acc:   77.18%
#
# Epoch 33/100
# --------------------
# Train Loss: 0.3978 | Train Acc: 86.19%
# Val Loss:   0.6870 | Val Acc:   77.32%
#
# Epoch 34/100
# --------------------
# Train Loss: 0.4268 | Train Acc: 84.50%
# Val Loss:   0.6617 | Val Acc:   77.18%
#
# Epoch 35/100
# --------------------
# Train Loss: 0.4062 | Train Acc: 85.40%
# Val Loss:   0.6174 | Val Acc:   79.30%
#
# Epoch 36/100
# --------------------
# Train Loss: 0.4235 | Train Acc: 84.14%
# Val Loss:   0.6165 | Val Acc:   79.01%
#
# Epoch 37/100
# --------------------
# Train Loss: 0.4200 | Train Acc: 84.47%
# Val Loss:   0.6395 | Val Acc:   77.61%
#
# Epoch 38/100
# --------------------
# Train Loss: 0.3985 | Train Acc: 86.34%
# Val Loss:   0.6324 | Val Acc:   80.14%
#
# Epoch 39/100
# --------------------
# Train Loss: 0.4024 | Train Acc: 85.50%
# Val Loss:   0.6582 | Val Acc:   78.73%
#
# Epoch 40/100
# --------------------
# Train Loss: 0.3958 | Train Acc: 86.04%
# Val Loss:   0.6879 | Val Acc:   76.76%
#
# Epoch 41/100
# --------------------
# Train Loss: 0.4045 | Train Acc: 85.56%
# Val Loss:   0.6219 | Val Acc:   80.00%
#
# Epoch 42/100
# --------------------
# Train Loss: 0.3759 | Train Acc: 86.82%
# Val Loss:   0.6799 | Val Acc:   78.17%
#
# Epoch 43/100
# --------------------
# Train Loss: 0.3936 | Train Acc: 85.34%
# Val Loss:   0.6838 | Val Acc:   77.89%
#
# Epoch 44/100
# --------------------
# Train Loss: 0.3902 | Train Acc: 85.92%
# Val Loss:   0.7712 | Val Acc:   74.23%
#
# Epoch 45/100
# --------------------
# Train Loss: 0.3849 | Train Acc: 86.19%
# Val Loss:   0.6326 | Val Acc:   80.42%
#
# Epoch 46/100
# --------------------
# Train Loss: 0.3859 | Train Acc: 85.95%
# Val Loss:   0.6406 | Val Acc:   79.30%
#
# Epoch 47/100
# --------------------
# Train Loss: 0.3726 | Train Acc: 86.31%
# Val Loss:   0.6110 | Val Acc:   80.56%
#
# Epoch 48/100
# --------------------
# Train Loss: 0.3699 | Train Acc: 87.12%
# Val Loss:   0.6382 | Val Acc:   80.00%
#
# Epoch 49/100
# --------------------
# Train Loss: 0.3937 | Train Acc: 85.80%
# Val Loss:   0.6412 | Val Acc:   78.17%
#
# Epoch 50/100
# --------------------
# Train Loss: 0.3925 | Train Acc: 86.04%
# Val Loss:   0.6624 | Val Acc:   78.73%
#
# Epoch 51/100
# --------------------
# Train Loss: 0.3703 | Train Acc: 86.85%
# Val Loss:   0.5913 | Val Acc:   80.70%
#
# Epoch 52/100
# --------------------
# Train Loss: 0.3960 | Train Acc: 86.25%
# Val Loss:   0.6397 | Val Acc:   79.72%
#
# Epoch 53/100
# --------------------
# Train Loss: 0.3768 | Train Acc: 85.80%
# Val Loss:   0.6019 | Val Acc:   81.69%
#
# Epoch 54/100
# --------------------
# Train Loss: 0.3720 | Train Acc: 86.67%
# Val Loss:   0.6358 | Val Acc:   80.99%
#
# Epoch 55/100
# --------------------
# Train Loss: 0.3920 | Train Acc: 86.31%
# Val Loss:   0.6383 | Val Acc:   79.30%
#
# Epoch 56/100
# --------------------
# Train Loss: 0.3546 | Train Acc: 86.67%
# Val Loss:   0.5848 | Val Acc:   81.69%
#
# Epoch 57/100
# --------------------
# Train Loss: 0.3830 | Train Acc: 86.37%
# Val Loss:   0.7506 | Val Acc:   77.04%
#
# Epoch 58/100
# --------------------
# Train Loss: 0.3684 | Train Acc: 86.85%
# Val Loss:   0.6196 | Val Acc:   80.85%
#
# Epoch 59/100
# --------------------
# Train Loss: 0.3352 | Train Acc: 88.05%
# Val Loss:   0.5997 | Val Acc:   80.85%
#
# Epoch 60/100
# --------------------
# Train Loss: 0.3525 | Train Acc: 87.72%
# Val Loss:   0.6790 | Val Acc:   78.17%
#
# Epoch 61/100
# --------------------
# Train Loss: 0.3623 | Train Acc: 86.94%
# Val Loss:   0.6141 | Val Acc:   81.41%
#
# Epoch 62/100
# --------------------
# Train Loss: 0.3615 | Train Acc: 87.18%
# Val Loss:   0.6197 | Val Acc:   80.70%
#
# Epoch 63/100
# --------------------
# Train Loss: 0.3601 | Train Acc: 87.18%
# Val Loss:   0.5925 | Val Acc:   81.83%
#
# Epoch 64/100
# --------------------
# Train Loss: 0.3587 | Train Acc: 87.48%
# Val Loss:   0.5957 | Val Acc:   82.68%
#
# Epoch 65/100
# --------------------
# Train Loss: 0.3265 | Train Acc: 88.87%
# Val Loss:   0.6475 | Val Acc:   79.86%
#
# Epoch 66/100
# --------------------
# Train Loss: 0.3466 | Train Acc: 86.97%
# Val Loss:   0.6714 | Val Acc:   79.72%
#
# Epoch 67/100
# --------------------
# Train Loss: 0.3474 | Train Acc: 87.36%
# Val Loss:   0.5835 | Val Acc:   81.69%
#
# Epoch 68/100
# --------------------
# Train Loss: 0.3620 | Train Acc: 87.27%
# Val Loss:   0.6214 | Val Acc:   80.28%
#
# Epoch 69/100
# --------------------
# Train Loss: 0.3558 | Train Acc: 87.39%
# Val Loss:   0.6641 | Val Acc:   80.00%
#
# Epoch 70/100
# --------------------
# Train Loss: 0.3185 | Train Acc: 88.62%
# Val Loss:   0.6645 | Val Acc:   78.73%
#
# Epoch 71/100
# --------------------
# Train Loss: 0.3256 | Train Acc: 88.47%
# Val Loss:   0.7128 | Val Acc:   78.87%
#
# Epoch 72/100
# --------------------
# Train Loss: 0.3436 | Train Acc: 87.12%
# Val Loss:   0.5741 | Val Acc:   81.13%
#
# Epoch 73/100
# --------------------
# Train Loss: 0.3365 | Train Acc: 87.57%
# Val Loss:   0.6409 | Val Acc:   78.73%
#
# Epoch 74/100
# --------------------
# Train Loss: 0.3324 | Train Acc: 88.35%
# Val Loss:   0.6228 | Val Acc:   80.99%
#
# Epoch 75/100
# --------------------
# Train Loss: 0.3271 | Train Acc: 87.99%
# Val Loss:   0.6647 | Val Acc:   78.73%
#
# Epoch 76/100
# --------------------
# Train Loss: 0.3351 | Train Acc: 88.02%
# Val Loss:   0.6204 | Val Acc:   81.55%
#
# Epoch 77/100
# --------------------
# Train Loss: 0.3191 | Train Acc: 89.23%
# Val Loss:   0.6043 | Val Acc:   82.11%
#
# Epoch 78/100
# --------------------
# Train Loss: 0.3117 | Train Acc: 89.11%
# Val Loss:   0.5940 | Val Acc:   81.83%
#
# Epoch 79/100
# --------------------
# Train Loss: 0.3170 | Train Acc: 88.44%
# Val Loss:   0.7050 | Val Acc:   79.30%
#
# Epoch 80/100
# --------------------
# Train Loss: 0.3211 | Train Acc: 88.47%
# Val Loss:   0.5963 | Val Acc:   80.42%
#
# Epoch 81/100
# --------------------
# Train Loss: 0.3461 | Train Acc: 87.54%
# Val Loss:   0.6660 | Val Acc:   80.28%
#
# Epoch 82/100
# --------------------
# Train Loss: 0.3233 | Train Acc: 88.65%
# Val Loss:   0.6012 | Val Acc:   81.41%
#
# Epoch 83/100
# --------------------
# Train Loss: 0.3205 | Train Acc: 88.59%
# Val Loss:   0.5977 | Val Acc:   81.13%
#
# Epoch 84/100
# --------------------
# Train Loss: 0.3079 | Train Acc: 88.72%
# Val Loss:   0.6455 | Val Acc:   79.44%
#
# Epoch 85/100
# --------------------
# Train Loss: 0.3219 | Train Acc: 88.75%
# Val Loss:   0.5864 | Val Acc:   80.70%
#
# Epoch 86/100
# --------------------
# Train Loss: 0.3221 | Train Acc: 88.05%
# Val Loss:   0.6170 | Val Acc:   79.72%
#
# Epoch 87/100
# --------------------
# Train Loss: 0.3098 | Train Acc: 88.90%
# Val Loss:   0.6230 | Val Acc:   80.28%
#
# Epoch 88/100
# --------------------
# Train Loss: 0.2989 | Train Acc: 89.77%
# Val Loss:   0.6223 | Val Acc:   80.42%
#
# Epoch 89/100
# --------------------
# Train Loss: 0.3148 | Train Acc: 88.78%
# Val Loss:   0.6003 | Val Acc:   80.70%
#
# Epoch 90/100
# --------------------
# Train Loss: 0.3088 | Train Acc: 89.11%
# Val Loss:   0.5942 | Val Acc:   80.42%
#
# Epoch 91/100
# --------------------
# Train Loss: 0.3106 | Train Acc: 89.05%
# Val Loss:   0.6007 | Val Acc:   81.27%
#
# Epoch 92/100
# --------------------
# Train Loss: 0.3114 | Train Acc: 89.02%
# Val Loss:   0.6022 | Val Acc:   81.41%
#
# Epoch 93/100
# --------------------
# Train Loss: 0.2883 | Train Acc: 89.74%
# Val Loss:   0.5974 | Val Acc:   81.69%
#
# Epoch 94/100
# --------------------
# Train Loss: 0.2957 | Train Acc: 89.14%
# Val Loss:   0.6271 | Val Acc:   79.86%
#
# Epoch 95/100
# --------------------
# Train Loss: 0.3200 | Train Acc: 88.84%
# Val Loss:   0.7027 | Val Acc:   79.58%
#
# Epoch 96/100
# --------------------
# Train Loss: 0.2836 | Train Acc: 89.62%
# Val Loss:   0.6029 | Val Acc:   81.41%
#
# Epoch 97/100
# --------------------
# Train Loss: 0.3146 | Train Acc: 89.02%
# Val Loss:   0.6019 | Val Acc:   81.41%
#
# Epoch 98/100
# --------------------
# Train Loss: 0.3018 | Train Acc: 89.44%
# Val Loss:   0.5828 | Val Acc:   81.69%
#
# Epoch 99/100
# --------------------
# Train Loss: 0.2892 | Train Acc: 90.01%
# Val Loss:   0.6400 | Val Acc:   80.42%
#
# Epoch 100/100
# --------------------
# Train Loss: 0.3152 | Train Acc: 88.78%
# Val Loss:   0.6875 | Val Acc:   79.58%

# %%
plt.figure(figsize=(8,5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Set model to evaluation mode
resnet50.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = resnet50(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Convert to numpy arrays
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# %%
print("Classification Report:\n")
print(classification_report(all_labels, all_preds, target_names=test_dataset.classes))
# Out:
# Classification Report:
#
#                      precision    recall  f1-score   support
#
#           Cardboard       0.81      0.81      0.81        70
#       Food Organics       0.95      0.90      0.93        63
#               Glass       0.88      0.71      0.79        63
#               Metal       0.65      0.86      0.74       119
# Miscellaneous Trash       0.78      0.67      0.72        75
#               Paper       0.92      0.64      0.76        75
#             Plastic       0.74      0.82      0.78       139
#       Textile Trash       0.81      0.71      0.76        49
#          Vegetation       0.93      0.97      0.95        66
#
#            accuracy                           0.80       719
#           macro avg       0.83      0.79      0.80       719
#        weighted avg       0.81      0.80      0.80       719

# %%
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
# Load pretrained DenseNet121
densenet = models.densenet121(pretrained=True)

# Freeze feature layers
for param in densenet.features.parameters():
    param.requires_grad = False

# Replace classifier layer
num_features = densenet.classifier.in_features
num_classes = len(train_dataset.classes)  # should be 9
densenet.classifier = nn.Linear(num_features, num_classes)

# Move to device (GPU if available)
densenet = densenet.to(device)

print("DenseNet121 modified successfully. Ready for training.")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 172MB/s]
# DenseNet121 modified successfully. Ready for training.

# %%
criterion_dense = nn.CrossEntropyLoss()
optimizer_dense = optim.Adam(densenet.classifier.parameters(), lr=0.001)

# %%
num_epochs = 100  
densenet, train_losses_dense, val_losses_dense = train_model(
    densenet, criterion_dense, optimizer_dense, train_loader, val_loader, num_epochs=num_epochs
)
# Out:
# Epoch 1/100
# --------------------
# Train Loss: 1.5330 | Train Acc: 49.56%
# Val Loss:   1.1311 | Val Acc:   63.52%
#
# Epoch 2/100
# --------------------
# Train Loss: 0.9987 | Train Acc: 68.52%
# Val Loss:   0.9266 | Val Acc:   68.03%
#
# Epoch 3/100
# --------------------
# Train Loss: 0.8315 | Train Acc: 74.21%
# Val Loss:   0.8324 | Val Acc:   72.39%
#
# Epoch 4/100
# --------------------
# Train Loss: 0.7567 | Train Acc: 75.96%
# Val Loss:   0.7799 | Val Acc:   73.80%
#
# Epoch 5/100
# --------------------
# Train Loss: 0.6918 | Train Acc: 77.70%
# Val Loss:   0.7455 | Val Acc:   73.10%
#
# Epoch 6/100
# --------------------
# Train Loss: 0.6469 | Train Acc: 78.93%
# Val Loss:   0.7494 | Val Acc:   73.66%
#
# Epoch 7/100
# --------------------
# Train Loss: 0.6218 | Train Acc: 78.21%
# Val Loss:   0.7267 | Val Acc:   73.66%
#
# Epoch 8/100
# --------------------
# Train Loss: 0.5812 | Train Acc: 80.56%
# Val Loss:   0.6755 | Val Acc:   76.90%
#
# Epoch 9/100
# --------------------
# Train Loss: 0.5812 | Train Acc: 81.37%
# Val Loss:   0.6734 | Val Acc:   76.34%
#
# Epoch 10/100
# --------------------
# Train Loss: 0.5409 | Train Acc: 81.97%
# Val Loss:   0.6582 | Val Acc:   77.46%
#
# Epoch 11/100
# --------------------
# Train Loss: 0.5401 | Train Acc: 81.88%
# Val Loss:   0.6557 | Val Acc:   77.61%
#
# Epoch 12/100
# --------------------
# Train Loss: 0.5064 | Train Acc: 83.84%
# Val Loss:   0.6306 | Val Acc:   80.00%
#
# Epoch 13/100
# --------------------
# Train Loss: 0.5134 | Train Acc: 82.46%
# Val Loss:   0.6333 | Val Acc:   78.17%
#
# Epoch 14/100
# --------------------
# Train Loss: 0.5003 | Train Acc: 82.88%
# Val Loss:   0.6265 | Val Acc:   79.01%
#
# Epoch 15/100
# --------------------
# Train Loss: 0.4952 | Train Acc: 83.69%
# Val Loss:   0.5908 | Val Acc:   81.13%
#
# Epoch 16/100
# --------------------
# Train Loss: 0.4698 | Train Acc: 84.68%
# Val Loss:   0.6132 | Val Acc:   80.00%
#
# Epoch 17/100
# --------------------
# Train Loss: 0.4787 | Train Acc: 83.93%
# Val Loss:   0.5889 | Val Acc:   80.00%
#
# Epoch 18/100
# --------------------
# Train Loss: 0.4538 | Train Acc: 84.83%
# Val Loss:   0.6055 | Val Acc:   79.72%
#
# Epoch 19/100
# --------------------
# Train Loss: 0.4661 | Train Acc: 83.36%
# Val Loss:   0.6126 | Val Acc:   79.44%
#
# Epoch 20/100
# --------------------
# Train Loss: 0.4531 | Train Acc: 84.62%
# Val Loss:   0.5951 | Val Acc:   80.14%
#
# Epoch 21/100
# --------------------
# Train Loss: 0.4414 | Train Acc: 85.13%
# Val Loss:   0.5807 | Val Acc:   80.14%
#
# Epoch 22/100
# --------------------
# Train Loss: 0.4389 | Train Acc: 85.89%
# Val Loss:   0.5791 | Val Acc:   79.44%
#
# Epoch 23/100
# --------------------
# Train Loss: 0.4397 | Train Acc: 85.37%
# Val Loss:   0.5678 | Val Acc:   81.55%
#
# Epoch 24/100
# --------------------
# Train Loss: 0.4343 | Train Acc: 85.16%
# Val Loss:   0.5738 | Val Acc:   80.28%
#
# Epoch 25/100
# --------------------
# Train Loss: 0.4238 | Train Acc: 85.59%
# Val Loss:   0.5602 | Val Acc:   81.97%
#
# Epoch 26/100
# --------------------
# Train Loss: 0.4231 | Train Acc: 85.46%
# Val Loss:   0.5651 | Val Acc:   80.42%
#
# Epoch 27/100
# --------------------
# Train Loss: 0.4236 | Train Acc: 85.28%
# Val Loss:   0.5585 | Val Acc:   82.39%
#
# Epoch 28/100
# --------------------
# Train Loss: 0.4058 | Train Acc: 86.25%
# Val Loss:   0.5605 | Val Acc:   81.69%
#
# Epoch 29/100
# --------------------
# Train Loss: 0.4109 | Train Acc: 85.95%
# Val Loss:   0.5671 | Val Acc:   81.83%
#
# Epoch 30/100
# --------------------
# Train Loss: 0.4143 | Train Acc: 85.77%
# Val Loss:   0.5702 | Val Acc:   80.28%
#
# Epoch 31/100
# --------------------
# Train Loss: 0.4068 | Train Acc: 86.01%
# Val Loss:   0.5745 | Val Acc:   79.30%
#
# Epoch 32/100
# --------------------
# Train Loss: 0.3989 | Train Acc: 86.37%
# Val Loss:   0.5811 | Val Acc:   79.01%
#
# Epoch 33/100
# --------------------
# Train Loss: 0.3946 | Train Acc: 86.01%
# Val Loss:   0.5505 | Val Acc:   81.55%
#
# Epoch 34/100
# --------------------
# Train Loss: 0.3944 | Train Acc: 85.98%
# Val Loss:   0.5995 | Val Acc:   77.61%
#
# Epoch 35/100
# --------------------
# Train Loss: 0.3857 | Train Acc: 86.22%
# Val Loss:   0.5455 | Val Acc:   81.41%
#
# Epoch 36/100
# --------------------
# Train Loss: 0.3818 | Train Acc: 86.49%
# Val Loss:   0.5573 | Val Acc:   79.44%
#
# Epoch 37/100
# --------------------
# Train Loss: 0.3889 | Train Acc: 86.70%
# Val Loss:   0.5922 | Val Acc:   78.31%
#
# Epoch 38/100
# --------------------
# Train Loss: 0.3861 | Train Acc: 85.95%
# Val Loss:   0.5709 | Val Acc:   79.15%
#
# Epoch 39/100
# --------------------
# Train Loss: 0.3841 | Train Acc: 86.94%
# Val Loss:   0.5866 | Val Acc:   80.00%
#
# Epoch 40/100
# --------------------
# Train Loss: 0.3718 | Train Acc: 87.24%
# Val Loss:   0.5411 | Val Acc:   82.54%
#
# Epoch 41/100
# --------------------
# Train Loss: 0.3690 | Train Acc: 87.15%
# Val Loss:   0.5508 | Val Acc:   81.97%
#
# Epoch 42/100
# --------------------
# Train Loss: 0.3654 | Train Acc: 86.55%
# Val Loss:   0.5575 | Val Acc:   81.69%
#
# Epoch 43/100
# --------------------
# Train Loss: 0.3712 | Train Acc: 87.09%
# Val Loss:   0.5557 | Val Acc:   80.99%
#
# Epoch 44/100
# --------------------
# Train Loss: 0.3819 | Train Acc: 86.94%
# Val Loss:   0.5378 | Val Acc:   81.55%
#
# Epoch 45/100
# --------------------
# Train Loss: 0.3835 | Train Acc: 86.13%
# Val Loss:   0.5577 | Val Acc:   80.99%
#
# Epoch 46/100
# --------------------
# Train Loss: 0.3698 | Train Acc: 87.39%
# Val Loss:   0.5459 | Val Acc:   80.85%
#
# Epoch 47/100
# --------------------
# Train Loss: 0.3501 | Train Acc: 87.36%
# Val Loss:   0.5569 | Val Acc:   81.27%
#
# Epoch 48/100
# --------------------
# Train Loss: 0.3643 | Train Acc: 87.36%
# Val Loss:   0.5536 | Val Acc:   79.72%
#
# Epoch 49/100
# --------------------
# Train Loss: 0.3710 | Train Acc: 87.09%
# Val Loss:   0.5570 | Val Acc:   80.14%
#
# Epoch 50/100
# --------------------
# Train Loss: 0.3630 | Train Acc: 87.66%
# Val Loss:   0.5830 | Val Acc:   80.28%
#
# Epoch 51/100
# --------------------
# Train Loss: 0.3551 | Train Acc: 87.15%
# Val Loss:   0.5615 | Val Acc:   80.56%
#
# Epoch 52/100
# --------------------
# Train Loss: 0.3718 | Train Acc: 87.03%
# Val Loss:   0.5672 | Val Acc:   81.41%
#
# Epoch 53/100
# --------------------
# Train Loss: 0.3412 | Train Acc: 88.38%
# Val Loss:   0.5489 | Val Acc:   81.41%
#
# Epoch 54/100
# --------------------
# Train Loss: 0.3519 | Train Acc: 87.81%
# Val Loss:   0.5466 | Val Acc:   81.41%
#
# Epoch 55/100
# --------------------
# Train Loss: 0.3505 | Train Acc: 87.66%
# Val Loss:   0.5521 | Val Acc:   82.25%
#
# Epoch 56/100
# --------------------
# Train Loss: 0.3391 | Train Acc: 88.44%
# Val Loss:   0.5373 | Val Acc:   80.56%
#
# Epoch 57/100
# --------------------
# Train Loss: 0.3607 | Train Acc: 87.51%
# Val Loss:   0.5645 | Val Acc:   81.69%
#
# Epoch 58/100
# --------------------
# Train Loss: 0.3359 | Train Acc: 88.08%
# Val Loss:   0.5851 | Val Acc:   80.85%
#
# Epoch 59/100
# --------------------
# Train Loss: 0.3465 | Train Acc: 87.27%
# Val Loss:   0.5651 | Val Acc:   80.56%
#
# Epoch 60/100
# --------------------
# Train Loss: 0.3485 | Train Acc: 87.69%
# Val Loss:   0.5596 | Val Acc:   81.69%
#
# Epoch 61/100
# --------------------
# Train Loss: 0.3567 | Train Acc: 87.42%
# Val Loss:   0.5784 | Val Acc:   81.83%
#
# Epoch 62/100
# --------------------
# Train Loss: 0.3360 | Train Acc: 88.26%
# Val Loss:   0.5470 | Val Acc:   82.39%
#
# Epoch 63/100
# --------------------
# Train Loss: 0.3326 | Train Acc: 88.05%
# Val Loss:   0.5803 | Val Acc:   81.13%
#
# Epoch 64/100
# --------------------
# Train Loss: 0.3327 | Train Acc: 88.44%
# Val Loss:   0.5674 | Val Acc:   81.69%
#
# Epoch 65/100
# --------------------
# Train Loss: 0.3285 | Train Acc: 87.99%
# Val Loss:   0.5568 | Val Acc:   81.69%
#
# Epoch 66/100
# --------------------
# Train Loss: 0.3261 | Train Acc: 88.08%
# Val Loss:   0.5398 | Val Acc:   82.39%
#
# Epoch 67/100
# --------------------
# Train Loss: 0.3222 | Train Acc: 88.93%
# Val Loss:   0.5415 | Val Acc:   82.54%
#
# Epoch 68/100
# --------------------
# Train Loss: 0.3327 | Train Acc: 87.78%
# Val Loss:   0.5713 | Val Acc:   80.00%
#
# Epoch 69/100
# --------------------
# Train Loss: 0.3333 | Train Acc: 87.72%
# Val Loss:   0.5564 | Val Acc:   80.70%
#
# Epoch 70/100
# --------------------
# Train Loss: 0.3374 | Train Acc: 87.48%
# Val Loss:   0.5676 | Val Acc:   80.99%
#
# Epoch 71/100
# --------------------
# Train Loss: 0.3451 | Train Acc: 87.60%
# Val Loss:   0.5590 | Val Acc:   80.99%
#
# Epoch 72/100
# --------------------
# Train Loss: 0.3648 | Train Acc: 87.18%
# Val Loss:   0.5682 | Val Acc:   81.69%
#
# Epoch 73/100
# --------------------
# Train Loss: 0.3335 | Train Acc: 88.05%
# Val Loss:   0.5652 | Val Acc:   81.69%
#
# Epoch 74/100
# --------------------
# Train Loss: 0.3429 | Train Acc: 87.60%
# Val Loss:   0.5649 | Val Acc:   82.96%
#
# Epoch 75/100
# --------------------
# Train Loss: 0.3353 | Train Acc: 87.99%
# Val Loss:   0.5541 | Val Acc:   81.13%
#
# Epoch 76/100
# --------------------
# Train Loss: 0.3268 | Train Acc: 88.29%
# Val Loss:   0.5578 | Val Acc:   81.41%
#
# Epoch 77/100
# --------------------
# Train Loss: 0.3473 | Train Acc: 87.27%
# Val Loss:   0.5626 | Val Acc:   80.56%
#
# Epoch 78/100
# --------------------
# Train Loss: 0.3267 | Train Acc: 87.96%
# Val Loss:   0.5366 | Val Acc:   81.97%
#
# Epoch 79/100
# --------------------
# Train Loss: 0.3418 | Train Acc: 88.08%
# Val Loss:   0.5823 | Val Acc:   81.41%
#
# Epoch 80/100
# --------------------
# Train Loss: 0.3214 | Train Acc: 88.17%
# Val Loss:   0.5534 | Val Acc:   80.85%
#
# Epoch 81/100
# --------------------
# Train Loss: 0.3335 | Train Acc: 88.26%
# Val Loss:   0.5422 | Val Acc:   81.55%
#
# Epoch 82/100
# --------------------
# Train Loss: 0.3197 | Train Acc: 89.05%
# Val Loss:   0.5465 | Val Acc:   82.11%
#
# Epoch 83/100
# --------------------
# Train Loss: 0.3245 | Train Acc: 88.20%
# Val Loss:   0.5521 | Val Acc:   81.13%
#
# Epoch 84/100
# --------------------
# Train Loss: 0.3221 | Train Acc: 88.05%
# Val Loss:   0.5464 | Val Acc:   80.42%
#
# Epoch 85/100
# --------------------
# Train Loss: 0.3267 | Train Acc: 87.93%
# Val Loss:   0.5622 | Val Acc:   80.56%
#
# Epoch 86/100
# --------------------
# Train Loss: 0.3322 | Train Acc: 88.44%
# Val Loss:   0.5620 | Val Acc:   81.41%
#
# Epoch 87/100
# --------------------
# Train Loss: 0.3135 | Train Acc: 89.26%
# Val Loss:   0.5349 | Val Acc:   81.13%
#
# Epoch 88/100
# --------------------
# Train Loss: 0.3172 | Train Acc: 88.59%
# Val Loss:   0.5270 | Val Acc:   81.13%
#
# Epoch 89/100
# --------------------
# Train Loss: 0.3133 | Train Acc: 88.75%
# Val Loss:   0.5707 | Val Acc:   81.13%
#
# Epoch 90/100
# --------------------
# Train Loss: 0.3111 | Train Acc: 88.90%
# Val Loss:   0.5454 | Val Acc:   82.54%
#
# Epoch 91/100
# --------------------
# Train Loss: 0.3054 | Train Acc: 89.35%
# Val Loss:   0.5471 | Val Acc:   82.11%
#
# Epoch 92/100
# --------------------
# Train Loss: 0.3031 | Train Acc: 88.78%
# Val Loss:   0.5597 | Val Acc:   80.85%
#
# Epoch 93/100
# --------------------
# Train Loss: 0.3230 | Train Acc: 88.81%
# Val Loss:   0.5515 | Val Acc:   81.13%
#
# Epoch 94/100
# --------------------
# Train Loss: 0.3012 | Train Acc: 89.02%
# Val Loss:   0.5617 | Val Acc:   80.28%
#
# Epoch 95/100
# --------------------
# Train Loss: 0.2959 | Train Acc: 88.90%
# Val Loss:   0.5581 | Val Acc:   81.55%
#
# Epoch 96/100
# --------------------
# Train Loss: 0.3222 | Train Acc: 88.14%
# Val Loss:   0.5820 | Val Acc:   80.56%
#
# Epoch 97/100
# --------------------
# Train Loss: 0.3129 | Train Acc: 88.29%
# Val Loss:   0.5668 | Val Acc:   80.99%
#
# Epoch 98/100
# --------------------
# Train Loss: 0.3007 | Train Acc: 89.44%
# Val Loss:   0.5508 | Val Acc:   80.99%
#
# Epoch 99/100
# --------------------
# Train Loss: 0.3126 | Train Acc: 89.02%
# Val Loss:   0.5583 | Val Acc:   82.39%
#
# Epoch 100/100
# --------------------
# Train Loss: 0.3127 | Train Acc: 88.96%
# Val Loss:   0.5692 | Val Acc:   80.99%

# %%
# Evaluation (reuse same approach as before)
densenet.eval()

all_preds_dense = []
all_labels_dense = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = densenet(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds_dense.extend(preds.cpu().numpy())
        all_labels_dense.extend(labels.cpu().numpy())

all_preds_dense = np.array(all_preds_dense)
all_labels_dense = np.array(all_labels_dense)

# Classification report
print("DenseNet121 Classification Report:\n")
print(classification_report(all_labels_dense, all_preds_dense, target_names=test_dataset.classes))

# Confusion matrix
cm_dense = confusion_matrix(all_labels_dense, all_preds_dense)
plt.figure(figsize=(8,6))
sns.heatmap(cm_dense, annot=True, fmt="d",
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("DenseNet121 Confusion Matrix")
plt.show()
# Out:
# DenseNet121 Classification Report:
#
#                      precision    recall  f1-score   support
#
#           Cardboard       0.83      0.86      0.85        70
#       Food Organics       0.88      0.94      0.91        63
#               Glass       0.79      0.87      0.83        63
#               Metal       0.71      0.92      0.80       119
# Miscellaneous Trash       0.74      0.53      0.62        75
#               Paper       0.87      0.71      0.78        75
#             Plastic       0.82      0.68      0.75       139
#       Textile Trash       0.77      0.84      0.80        49
#          Vegetation       0.92      1.00      0.96        66
#
#            accuracy                           0.80       719
#           macro avg       0.81      0.82      0.81       719
#        weighted avg       0.81      0.80      0.80       719
